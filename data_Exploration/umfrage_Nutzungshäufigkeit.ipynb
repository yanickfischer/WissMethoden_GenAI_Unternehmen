# %% [markdown]
# # Auswertung Generative KI Umfrage
#
# Dieses Notebook dient der explorativen Datenanalyse der Umfrage zur Nutzung von Generativer KI im Unternehmenskontext.
# Bitte stelle sicher, dass die Datei `results-survey.csv` im gleichen Verzeichnis liegt und korrekt formatiert ist.

# %%
# Pakete importieren
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Anzeigeoptionen
pd.set_option('display.max_columns', None)
sns.set(style='whitegrid')

# %%
# CSV-Datei laden (Dateiname ggf. anpassen)
file_path = 'results-survey.csv'
df = pd.read_csv(file_path)
df.head()
# Out:
#    Antwort ID Datum Abgeschickt  Letzte Seite Start-Sprache  \
# 0           1  09.04.2025 16:37            14            de
# 1           2  09.04.2025 16:40            14            de
# 2           3  09.04.2025 16:39            14            de
# 3           4  09.04.2025 16:42            14            de
# 4           5  09.04.2025 17:02            14            de
#
#    Zufallsgeneratorstartwert   Datum gestartet Datum letzte Aktivität  \
# 0                  983817554  09.04.2025 16:34       09.04.2025 16:37
# 1                 1394169063  09.04.2025 16:35       09.04.2025 16:40
# 2                 1239400235  09.04.2025 16:35       09.04.2025 16:39
# 3                 1790326057  09.04.2025 16:38       09.04.2025 16:42
# 4                  177762799  09.04.2025 16:52       09.04.2025 17:02
#
#   Bitte geben Sie Ihren Nachnamen an: Bitte geben Sie Ihren Vornamen an:  \
# 0                             Aleksic                             Nikola
# 1                              Jakupi                               Leon
# 2                               Saban                            Huseini
# 3                              Ferati                               Anes
# 4                              Zwicky                             Pascal
#
#   Bitte geben Sie Ihr Geschlecht an: Bitte geben Sie Ihre Altersgruppe an:  \
# 0                           Männlich                                 18-25
# 1                           Männlich                                 18-25
# 2                           Männlich                                 26-35
# 3                           Männlich                                 18-25
# 4                           Männlich                                 26-35
#
#   Bitte geben Sie Ihre Studenten E-Mail Adresse ein:  \
# 0                          Aleksnik@students.zhaw.ch
# 1                            ljakupi@ipso.student.ch
# 2                           saban.huseini@icloud.com
# 3                          Feratane@students.zhaw.ch
# 4                        pascal.zwicky@stud.unilu.ch
#
#    Wie häufig nutzen Sie aktuell generative KI im Arbeitskontext? [Benutzung KI]  \
# 0                                                  7
# 1                                                  7
# 2                                                  4
# 3                                                  9
# 4                                                  8
#
#                                            Kommentar  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  Oft, nicht täglich, genutzt alsInformationssuc...
#
#   Wo setzen Sie Generative KI typischerweise ein? [Texterstellung und -bearbeitung (z.B. Verfassung von Mails, Artikel oder Zusammenfassungen)]  \
# 0                                                 Ja
# 1                                                 Ja
# 2                                                 Ja
# 3                                                 Ja
# 4                                                 Ja
#
#   Wo setzen Sie Generative KI typischerweise ein? [Kreative Inhalte erstellen (z.B. Bilder, Musik, Videos, Designs etc.)]  \
# 0                                               Nein
# 1                                               Nein
# 2                                               Nein
# 3                                               Nein
# 4                                               Nein
#
#   Wo setzen Sie Generative KI typischerweise ein? [Programmieren und Automatisieren (z.B. Code schreiben, Fehler beheben etc.)]  \
# 0                                                 Ja
# 1                                               Nein
# 2                                               Nein
# 3                                                 Ja
# 4                                               Nein
#
#   Wo setzen Sie Generative KI typischerweise ein? [Lernen und Bildung (z.B. individuelle Erklärungen, Zusammenfassungen, Lernhilfe etc.)]  \
# 0                                                 Ja
# 1                                                 Ja
# 2                                                 Ja
# 3                                                 Ja
# 4                                                 Ja
#
#   Wo setzen Sie Generative KI typischerweise ein? [Kommunikation und Übersetzung verbessern (z.B. Korrektur von Texten, Übersetzungen von Artikeln etc.)]  \
# 0                                               Nein
# 1                                                 Ja
# 2                                               Nein
# 3                                                 Ja
# 4                                                 Ja
#
#                                          Kommentar.1  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  Zudem noch Apple AI für die Sortierung und Pri...
#
#   Welche Erwartungen hatten Sie an die Generative KI vor der Nutzung? [Effizienz]  \
# 0                               Neutrale Erwartungen
# 1                               Neutrale Erwartungen
# 2                                   Hohe Erwartungen
# 3                                  Keine Erwartungen
# 4                              Sehr hohe Erwartungen
#
#   Welche Erwartungen hatten Sie an die Generative KI vor der Nutzung? [Kreativität]  \
# 0                                  Wenig Erwartungen
# 1                                  Wenig Erwartungen
# 2                                   Hohe Erwartungen
# 3                                   Hohe Erwartungen
# 4                                  Wenig Erwartungen
#
#   Welche Erwartungen hatten Sie an die Generative KI vor der Nutzung? [Arbeitsentlastung]  \
# 0                                   Hohe Erwartungen
# 1                               Neutrale Erwartungen
# 2                              Sehr hohe Erwartungen
# 3                                  Wenig Erwartungen
# 4                              Sehr hohe Erwartungen
#
#   Welche Erwartungen hatten Sie an die Generative KI vor der Nutzung? [Zuverlässigkeit]  \
# 0                                   Hohe Erwartungen
# 1                                  Wenig Erwartungen
# 2                              Sehr hohe Erwartungen
# 3                               Neutrale Erwartungen
# 4                               Neutrale Erwartungen
#
#   Welche Erwartungen hatten Sie an die Generative KI vor der Nutzung? [Innovation]  \
# 0                              Sehr hohe Erwartungen
# 1                                  Wenig Erwartungen
# 2                                   Hohe Erwartungen
# 3                               Neutrale Erwartungen
# 4                                  Wenig Erwartungen
#
#   Kommentar.2 Welche dieser Erwartungen wurden erfüllt? [Effizienz][Skala 1]  \
# 0         NaN                               Neutrale Erwartungen
# 1         NaN                                  Wenig Erwartungen
# 2         NaN                                   Hohe Erwartungen
# 3         NaN                               Neutrale Erwartungen
# 4         NaN                              Sehr hohe Erwartungen
#
#   Welche dieser Erwartungen wurden erfüllt? [Effizienz][Skala 2]  \
# 0                                   Hohe Erwartungen
# 1                                   Hohe Erwartungen
# 2                                   Hohe Erwartungen
# 3                                   Hohe Erwartungen
# 4                                   Hohe Erwartungen
#
#   Welche dieser Erwartungen wurden erfüllt? [Kreativität][Skala 1]  \
# 0                                  Wenig Erwartungen
# 1                                  Wenig Erwartungen
# 2                                   Hohe Erwartungen
# 3                               Neutrale Erwartungen
# 4                                  Wenig Erwartungen
#
#   Welche dieser Erwartungen wurden erfüllt? [Kreativität][Skala 2]  \
# 0                               Neutrale Erwartungen
# 1                              Sehr hohe Erwartungen
# 2                                   Hohe Erwartungen
# 3                                   Hohe Erwartungen
# 4                               Neutrale Erwartungen
#
#   Welche dieser Erwartungen wurden erfüllt? [Arbeitsentlastung][Skala 1]  \
# 0                                   Hohe Erwartungen
# 1                               Neutrale Erwartungen
# 2                                   Hohe Erwartungen
# 3                                  Wenig Erwartungen
# 4                                   Hohe Erwartungen
#
#   Welche dieser Erwartungen wurden erfüllt? [Arbeitsentlastung][Skala 2]  \
# 0                                   Hohe Erwartungen
# 1                                   Hohe Erwartungen
# 2                              Sehr hohe Erwartungen
# 3                                   Hohe Erwartungen
# 4                                   Hohe Erwartungen
#
#   Welche dieser Erwartungen wurden erfüllt? [Zuverlässigkeit][Skala 1]  \
# 0                                   Hohe Erwartungen
# 1                                  Wenig Erwartungen
# 2                                   Hohe Erwartungen
# 3                                  Wenig Erwartungen
# 4                               Neutrale Erwartungen
#
#   Welche dieser Erwartungen wurden erfüllt? [Zuverlässigkeit][Skala 2]  \
# 0                                   Hohe Erwartungen
# 1                                   Hohe Erwartungen
# 2                               Neutrale Erwartungen
# 3                                   Hohe Erwartungen
# 4                               Neutrale Erwartungen
#
#   Welche dieser Erwartungen wurden erfüllt? [Innovation][Skala 1]  \
# 0                              Sehr hohe Erwartungen
# 1                                  Wenig Erwartungen
# 2                               Neutrale Erwartungen
# 3                               Neutrale Erwartungen
# 4                                  Wenig Erwartungen
#
#   Welche dieser Erwartungen wurden erfüllt? [Innovation][Skala 2] Kommentar.3  \
# 0                                   Hohe Erwartungen                      NaN
# 1                              Sehr hohe Erwartungen                      NaN
# 2                                   Hohe Erwartungen                      NaN
# 3                                   Hohe Erwartungen                      NaN
# 4                                   Hohe Erwartungen                      NaN
#
#   Welche positiven Erfahrungen habe Sie mit Generativer KI gemacht? [Zeitersparnis]  \
# 0                                                 Ja
# 1                                                 Ja
# 2                                                 Ja
# 3                                                 Ja
# 4                                                 Ja
#
#   Welche positiven Erfahrungen habe Sie mit Generativer KI gemacht? [Kreative Impulse]  \
# 0                                               Nein
# 1                                                 Ja
# 2                                                 Ja
# 3                                               Nein
# 4                                               Nein
#
#   Welche positiven Erfahrungen habe Sie mit Generativer KI gemacht? [Entlastung (Zeit + Aufwand)]  \
# 0                                                 Ja
# 1                                                 Ja
# 2                                                 Ja
# 3                                                 Ja
# 4                                                 Ja
#
#   Welche positiven Erfahrungen habe Sie mit Generativer KI gemacht? [Qualität]  \
# 0                                                 Ja
# 1                                                 Ja
# 2                                               Nein
# 3                                                 Ja
# 4                                               Nein
#
#   Welche positiven Erfahrungen habe Sie mit Generativer KI gemacht? [Keine bemerkbaren Effekte]  \
# 0                                               Nein
# 1                                               Nein
# 2                                               Nein
# 3                                               Nein
# 4                                               Nein
#
#   Kommentar.4  \
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
#
#   Welche negativen Erfahrungen haben Sie mit Generativer KI gemacht? [Ungenaue Resultate]  \
# 0                                                 Ja
# 1                                               Nein
# 2                                                 Ja
# 3                                               Nein
# 4                                                 Ja
#
#   Welche negativen Erfahrungen haben Sie mit Generativer KI gemacht? [Fehlender Datenschutz]  \
# 0                                               Nein
# 1                                               Nein
# 2                                               Nein
# 3                                               Nein
# 4                                               Nein
#
#   Welche negativen Erfahrungen haben Sie mit Generativer KI gemacht? [Verbreitung von Fehlinformationen (Fake News)]  \
# 0                                               Nein
# 1                                               Nein
# 2                                                 Ja
# 3                                               Nein
# 4                                               Nein
#
#   Welche negativen Erfahrungen haben Sie mit Generativer KI gemacht? [Abhängigkeit von Technologie]  \
# 0                                                 Ja
# 1                                               Nein
# 2                                                 Ja
# 3                                               Nein
# 4                                               Nein
#
#   Welche negativen Erfahrungen haben Sie mit Generativer KI gemacht? [Verlust von Originalität / menschlicher Kreativität]  \
# 0                                                 Ja
# 1                                                 Ja
# 2                                               Nein
# 3                                                 Ja
# 4                                               Nein
#
#   Kommentar.5 Wie stark vertrauen Sie den Resultaten von Generativer KI?  \
# 0         NaN                                    Hohes Vertrauen
# 1         NaN                                    Hohes Vertrauen
# 2         NaN                                Neutrales Vertrauen
# 3         NaN                                Neutrales Vertrauen
# 4         NaN                                Neutrales Vertrauen
#
#                                          Kommentar.6  \
# 0                                                NaN
# 1     Ich kontrolliere oftmals nach, zur Sicherheit.
# 2                                                NaN
# 3                                                NaN
# 4  Alles muss hinterfragt werde, die Antworten de...
#
#   Hat Generative KI Ihre Arbeitsweise verändert?  \
# 0                                             Ja
# 1                                             Ja
# 2                                             Ja
# 3                                             Ja
# 4                                             Ja
#
#                                          Kommentar.7  \
# 0                                                NaN
# 1              Ich arbeite viel lockerer als vorher.
# 2                                                NaN
# 3                                                NaN
# 4  Viele Muster und Grundvorlagen für ein schnell...
#
#   Wie kompetent fühlen Sie sich im Umgang mit Generativer KI? Kommentar.8  \
# 0                                     Gute Kompetenz                  NaN
# 1                                     Gute Kompetenz                  NaN
# 2                                     Gute Kompetenz                  NaN
# 3                                     Gute Kompetenz                  NaN
# 4                                     Gute Kompetenz                  NaN
#
#   Hatten Sie Schulungen oder Trainings im Zusammenhang mit Generativer KI?  \
# 0                                               Nein
# 1                                               Nein
# 2                                               Nein
# 3                                               Nein
# 4                                               Nein
#
#                         Kommentar.9  \
# 0                               NaN
# 1                               NaN
# 2                               NaN
# 3                               NaN
# 4  Learning by Doing, Online Videos
#
#   Wie gut unterstützt Ihr Unternehmen die Nutzung von Generativer KI? [Technologische Infrastruktur]  \
# 0                                  Zufriedenstellend
# 1                                  Zufriedenstellend
# 2                                                Gut
# 3                                              Wenig
# 4                                          Gar Nicht
#
#   Wie gut unterstützt Ihr Unternehmen die Nutzung von Generativer KI? [Guidelines zur Benutzung von Generativer KI]  \
# 0                                  Zufriedenstellend
# 1                                  Zufriedenstellend
# 2                                  Zufriedenstellend
# 3                                              Wenig
# 4                                          Gar Nicht
#
#   Wie gut unterstützt Ihr Unternehmen die Nutzung von Generativer KI? [Schulungen / Kurse / Webinare]  \
# 0                                  Zufriedenstellend
# 1                                              Wenig
# 2                                                Gut
# 3                                              Wenig
# 4                                          Gar Nicht
#
#   Wie gut unterstützt Ihr Unternehmen die Nutzung von Generativer KI? [Rechtliche Richtlinien]  \
# 0                                  Zufriedenstellend
# 1                                              Wenig
# 2                                                Gut
# 3                                              Wenig
# 4                                          Gar Nicht
#
#   Wie gut unterstützt Ihr Unternehmen die Nutzung von Generativer KI? [Kulturelle Offenheit]  \
# 0                                  Zufriedenstellend
# 1                                                Gut
# 2                                  Zufriedenstellend
# 3                                              Wenig
# 4                                          Gar Nicht
#
#   Kommentar.10  \
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
#
#    Würden Sie Generative KI Ihren Mitmenschen weiterempfehlen? [Weiterempfehlung]  \
# 0                                                 10
# 1                                                 10
# 2                                                  7
# 3                                                  8
# 4                                                  8
#
#   Kommentar.11 Planen Sie, Generative KI in Zukunft (mehr) zu nutzen?  \
# 0          NaN                                                 Ja
# 1          NaN                                                 Ja
# 2          NaN                                                 Ja
# 3          NaN                                                 Ja
# 4          NaN                                                 Ja
#
#                                         Kommentar.12
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  In allen Möglichkeiten, welche sich ergeben un...

# %% [markdown]
# ## Überblick über die Datenstruktur

# %%
# Struktur anzeigen, fehlende Werte analysieren
df.info()
df.isnull().sum().sort_values(ascending=False).head(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 47 entries, 0 to 46
# Data columns (total 67 columns):
#  #   Column                                                                                                                                                   Non-Null Count  Dtype
# ---  ------                                                                                                                                                   --------------  -----
#  0   Antwort ID                                                                                                                                               47 non-null     int64
#  1   Datum Abgeschickt                                                                                                                                        47 non-null     object
#  2   Letzte Seite                                                                                                                                             47 non-null     int64
#  3   Start-Sprache                                                                                                                                            47 non-null     object
#  4   Zufallsgeneratorstartwert                                                                                                                                47 non-null     int64
#  5   Datum gestartet                                                                                                                                          47 non-null     object
#  6   Datum letzte Aktivität                                                                                                                                   47 non-null     object
#  7   Bitte geben Sie Ihren Nachnamen an:                                                                                                                      47 non-null     object
#  8   Bitte geben Sie Ihren Vornamen an:                                                                                                                       47 non-null     object
#  9   Bitte geben Sie Ihr Geschlecht an:                                                                                                                       47 non-null     object
#  10  Bitte geben Sie Ihre Altersgruppe an:                                                                                                                    47 non-null     object
#  11  Bitte geben Sie Ihre Studenten E-Mail Adresse ein:                                                                                                       47 non-null     object
#  12  Wie häufig nutzen Sie aktuell generative KI im Arbeitskontext? [Benutzung KI]                                                                            47 non-null     int64
#  13  Kommentar                                                                                                                                                12 non-null     object
#  14  Wo setzen Sie Generative KI typischerweise ein? [Texterstellung und -bearbeitung (z.B. Verfassung von Mails, Artikel oder Zusammenfassungen)]            47 non-null     object
#  15  Wo setzen Sie Generative KI typischerweise ein? [Kreative Inhalte erstellen (z.B. Bilder, Musik, Videos, Designs etc.)]                                  47 non-null     object
#  16  Wo setzen Sie Generative KI typischerweise ein? [Programmieren und Automatisieren (z.B. Code schreiben, Fehler beheben etc.)]                            47 non-null     object
#  17  Wo setzen Sie Generative KI typischerweise ein? [Lernen und Bildung (z.B. individuelle Erklärungen, Zusammenfassungen, Lernhilfe etc.)]                  47 non-null     object
#  18  Wo setzen Sie Generative KI typischerweise ein? [Kommunikation und Übersetzung verbessern (z.B. Korrektur von Texten, Übersetzungen von Artikeln etc.)]  47 non-null     object
#  19  Kommentar.1                                                                                                                                              8 non-null      object
#  20  Welche Erwartungen hatten Sie an die Generative KI vor der Nutzung? [Effizienz]                                                                          47 non-null     object
#  21  Welche Erwartungen hatten Sie an die Generative KI vor der Nutzung? [Kreativität]                                                                        47 non-null     object
#  22  Welche Erwartungen hatten Sie an die Generative KI vor der Nutzung? [Arbeitsentlastung]                                                                  47 non-null     object
#  23  Welche Erwartungen hatten Sie an die Generative KI vor der Nutzung? [Zuverlässigkeit]                                                                    47 non-null     object
#  24  Welche Erwartungen hatten Sie an die Generative KI vor der Nutzung? [Innovation]                                                                         47 non-null     object
#  25  Kommentar.2                                                                                                                                              7 non-null      object
#  26  Welche dieser Erwartungen wurden erfüllt? [Effizienz][Skala 1]                                                                                           47 non-null     object
#  27  Welche dieser Erwartungen wurden erfüllt? [Effizienz][Skala 2]                                                                                           47 non-null     object
#  28  Welche dieser Erwartungen wurden erfüllt? [Kreativität][Skala 1]                                                                                         47 non-null     object
#  29  Welche dieser Erwartungen wurden erfüllt? [Kreativität][Skala 2]                                                                                         47 non-null     object
#  30  Welche dieser Erwartungen wurden erfüllt? [Arbeitsentlastung][Skala 1]                                                                                   47 non-null     object
#  31  Welche dieser Erwartungen wurden erfüllt? [Arbeitsentlastung][Skala 2]                                                                                   47 non-null     object
#  32  Welche dieser Erwartungen wurden erfüllt? [Zuverlässigkeit][Skala 1]                                                                                     47 non-null     object
#  33  Welche dieser Erwartungen wurden erfüllt? [Zuverlässigkeit][Skala 2]                                                                                     47 non-null     object
#  34  Welche dieser Erwartungen wurden erfüllt? [Innovation][Skala 1]                                                                                          47 non-null     object
#  35  Welche dieser Erwartungen wurden erfüllt? [Innovation][Skala 2]                                                                                          47 non-null     object
#  36  Kommentar.3                                                                                                                                              14 non-null     object
#  37  Welche positiven Erfahrungen habe Sie mit Generativer KI gemacht? [Zeitersparnis]                                                                        47 non-null     object
#  38  Welche positiven Erfahrungen habe Sie mit Generativer KI gemacht? [Kreative Impulse]                                                                     47 non-null     object
#  39  Welche positiven Erfahrungen habe Sie mit Generativer KI gemacht? [Entlastung (Zeit + Aufwand)]                                                          47 non-null     object
#  40  Welche positiven Erfahrungen habe Sie mit Generativer KI gemacht? [Qualität]                                                                             47 non-null     object
#  41  Welche positiven Erfahrungen habe Sie mit Generativer KI gemacht? [Keine bemerkbaren Effekte]                                                            47 non-null     object
#  42  Kommentar.4                                                                                                                                              7 non-null      object
#  43  Welche negativen Erfahrungen haben Sie mit Generativer KI gemacht? [Ungenaue Resultate]                                                                  47 non-null     object
#  44  Welche negativen Erfahrungen haben Sie mit Generativer KI gemacht? [Fehlender Datenschutz]                                                               47 non-null     object
#  45  Welche negativen Erfahrungen haben Sie mit Generativer KI gemacht? [Verbreitung von Fehlinformationen (Fake News)]                                       47 non-null     object
#  46  Welche negativen Erfahrungen haben Sie mit Generativer KI gemacht? [Abhängigkeit von Technologie]                                                        47 non-null     object
#  47  Welche negativen Erfahrungen haben Sie mit Generativer KI gemacht? [Verlust von Originalität / menschlicher Kreativität]                                 47 non-null     object
#  48  Kommentar.5                                                                                                                                              6 non-null      object
#  49  Wie stark vertrauen Sie den Resultaten von Generativer KI?                                                                                               47 non-null     object
#  50  Kommentar.6                                                                                                                                              10 non-null     object
#  51  Hat Generative KI Ihre Arbeitsweise verändert?                                                                                                           47 non-null     object
#  52  Kommentar.7                                                                                                                                              8 non-null      object
#  53  Wie kompetent fühlen Sie sich im Umgang mit Generativer KI?                                                                                              47 non-null     object
#  54  Kommentar.8                                                                                                                                              2 non-null      object
#  55  Hatten Sie Schulungen oder Trainings im Zusammenhang mit Generativer KI?                                                                                 47 non-null     object
#  56  Kommentar.9                                                                                                                                              3 non-null      object
#  57  Wie gut unterstützt Ihr Unternehmen die Nutzung von Generativer KI? [Technologische Infrastruktur]                                                       47 non-null     object
#  58  Wie gut unterstützt Ihr Unternehmen die Nutzung von Generativer KI? [Guidelines zur Benutzung von Generativer KI]                                        47 non-null     object
#  59  Wie gut unterstützt Ihr Unternehmen die Nutzung von Generativer KI? [Schulungen / Kurse / Webinare]                                                      47 non-null     object
#  60  Wie gut unterstützt Ihr Unternehmen die Nutzung von Generativer KI? [Rechtliche Richtlinien]                                                             47 non-null     object
#  61  Wie gut unterstützt Ihr Unternehmen die Nutzung von Generativer KI? [Kulturelle Offenheit]                                                               47 non-null     object
#  62  Kommentar.10                                                                                                                                             6 non-null      object
#  63  Würden Sie Generative KI Ihren Mitmenschen weiterempfehlen? [Weiterempfehlung]                                                                           47 non-null     int64
#  64  Kommentar.11                                                                                                                                             3 non-null      object
#  65  Planen Sie, Generative KI in Zukunft (mehr) zu nutzen?                                                                                                   47 non-null     object
#  66  Kommentar.12                                                                                                                                             3 non-null      object
# dtypes: int64(5), object(62)
# memory usage: 24.7+ KB
# Kommentar.8     45
# Kommentar.12    44
# Kommentar.11    44
# Kommentar.9     44
# Kommentar.10    41
# Kommentar.5     41
# Kommentar.4     40
# Kommentar.2     40
# Kommentar.1     39
# Kommentar.7     39
# dtype: int64

# %%
print(df.columns.tolist())
# Out:
# ['Antwort ID', 'Datum Abgeschickt', 'Letzte Seite', 'Start-Sprache', 'Zufallsgeneratorstartwert', 'Datum gestartet', 'Datum letzte Aktivität', 'Bitte geben Sie Ihren Nachnamen an:', 'Bitte geben Sie Ihren Vornamen an:', 'Bitte geben Sie Ihr Geschlecht an:', 'Bitte geben Sie Ihre Altersgruppe an:', 'Bitte geben Sie Ihre Studenten E-Mail Adresse ein:', 'Wie häufig nutzen Sie aktuell generative KI im Arbeitskontext? [Benutzung KI]', 'Kommentar', 'Wo setzen Sie Generative KI typischerweise ein? [Texterstellung und -bearbeitung (z.B. Verfassung von Mails, Artikel oder Zusammenfassungen)]', 'Wo setzen Sie Generative KI typischerweise ein? [Kreative Inhalte erstellen (z.B. Bilder, Musik, Videos, Designs etc.)]', 'Wo setzen Sie Generative KI typischerweise ein? [Programmieren und Automatisieren (z.B. Code schreiben, Fehler beheben etc.)]', 'Wo setzen Sie Generative KI typischerweise ein? [Lernen und Bildung (z.B. individuelle Erklärungen, Zusammenfassungen, Lernhilfe etc.)]', 'Wo setzen Sie Generative KI typischerweise ein? [Kommunikation und Übersetzung verbessern (z.B. Korrektur von Texten, Übersetzungen von Artikeln etc.)]', 'Kommentar.1', 'Welche Erwartungen hatten Sie an die Generative KI vor der Nutzung? [Effizienz]', 'Welche Erwartungen hatten Sie an die Generative KI vor der Nutzung? [Kreativität]', 'Welche Erwartungen hatten Sie an die Generative KI vor der Nutzung? [Arbeitsentlastung]', 'Welche Erwartungen hatten Sie an die Generative KI vor der Nutzung? [Zuverlässigkeit]', 'Welche Erwartungen hatten Sie an die Generative KI vor der Nutzung? [Innovation]', 'Kommentar.2', 'Welche dieser Erwartungen wurden erfüllt? [Effizienz][Skala 1]', 'Welche dieser Erwartungen wurden erfüllt? [Effizienz][Skala 2]', 'Welche dieser Erwartungen wurden erfüllt? [Kreativität][Skala 1]', 'Welche dieser Erwartungen wurden erfüllt? [Kreativität][Skala 2]', 'Welche dieser Erwartungen wurden erfüllt? [Arbeitsentlastung][Skala 1]', 'Welche dieser Erwartungen wurden erfüllt? [Arbeitsentlastung][Skala 2]', 'Welche dieser Erwartungen wurden erfüllt? [Zuverlässigkeit][Skala 1]', 'Welche dieser Erwartungen wurden erfüllt? [Zuverlässigkeit][Skala 2]', 'Welche dieser Erwartungen wurden erfüllt? [Innovation][Skala 1]', 'Welche dieser Erwartungen wurden erfüllt? [Innovation][Skala 2]', 'Kommentar.3', 'Welche positiven Erfahrungen habe Sie mit Generativer KI gemacht? [Zeitersparnis]', 'Welche positiven Erfahrungen habe Sie mit Generativer KI gemacht? [Kreative Impulse]', 'Welche positiven Erfahrungen habe Sie mit Generativer KI gemacht? [Entlastung (Zeit + Aufwand)]', 'Welche positiven Erfahrungen habe Sie mit Generativer KI gemacht? [Qualität]', 'Welche positiven Erfahrungen habe Sie mit Generativer KI gemacht? [Keine bemerkbaren Effekte]', 'Kommentar.4', 'Welche negativen Erfahrungen haben Sie mit Generativer KI gemacht? [Ungenaue Resultate]', 'Welche negativen Erfahrungen haben Sie mit Generativer KI gemacht? [Fehlender Datenschutz]', 'Welche negativen Erfahrungen haben Sie mit Generativer KI gemacht? [Verbreitung von Fehlinformationen (Fake News)]', 'Welche negativen Erfahrungen haben Sie mit Generativer KI gemacht? [Abhängigkeit von Technologie]', 'Welche negativen Erfahrungen haben Sie mit Generativer KI gemacht? [Verlust von Originalität / menschlicher Kreativität]', 'Kommentar.5', 'Wie stark vertrauen Sie den Resultaten von Generativer KI?', 'Kommentar.6', 'Hat Generative KI Ihre Arbeitsweise verändert?', 'Kommentar.7', 'Wie kompetent fühlen Sie sich im Umgang mit Generativer KI?', 'Kommentar.8', 'Hatten Sie Schulungen oder Trainings im Zusammenhang mit Generativer KI?', 'Kommentar.9', 'Wie gut unterstützt Ihr Unternehmen die Nutzung von Generativer KI? [Technologische Infrastruktur]', 'Wie gut unterstützt Ihr Unternehmen die Nutzung von Generativer KI? [Guidelines zur Benutzung von Generativer KI]', 'Wie gut unterstützt Ihr Unternehmen die Nutzung von Generativer KI? [Schulungen / Kurse / Webinare]', 'Wie gut unterstützt Ihr Unternehmen die Nutzung vo ...

# %% [markdown]
# ## 1.Nutzungshäufigkeit Arbeitskontext

# %%
# Beispiel: Histogramm zur Nutzung generativer KI
column = 'Wie häufig nutzen Sie aktuell generative KI im Arbeitskontext? [Benutzung KI]'
if column in df.columns:
    sns.histplot(df[column].dropna(), bins=10, kde=True)
    plt.title('Nutzungshäufigkeit Generative KI')
    plt.xlabel('Skala 0–10')
    plt.ylabel('Anzahl Antworten')
    plt.show()
else:
    print(f'Spalte "{column}" nicht gefunden.')

# %%
import numpy as np

# Exakte Spaltennamen gemäss deinem DataFrame
column = 'Wie häufig nutzen Sie aktuell generative KI im Arbeitskontext? [Benutzung KI]'
email_column = 'Bitte geben Sie Ihre Studenten E-Mail Adresse ein:'

# Prüfung, ob beide Spalten vorhanden sind
if column in df.columns and email_column in df.columns:

    # Gruppierung nach E-Mail-Endung
    df['ZHAW_Student'] = df[email_column].astype(str).str.endswith("@students.zhaw.ch")

    # Gruppenwerte extrahieren
    zhaw = df[df['ZHAW_Student'] == True][column].dropna()
    arbeit = df[df['ZHAW_Student'] == False][column].dropna()

    # Histogramm mit beiden Gruppen
    plt.figure(figsize=(10, 6))
    bins = np.linspace(0, 10, 11)

    sns.histplot(zhaw, bins=bins, color="blue", label="ZHAW-Studenten", kde=False, alpha=0.6)
    sns.histplot(arbeit, bins=bins, color="green", label="Arbeitnehmende", kde=False, alpha=0.6)

    plt.title("Nutzungshäufigkeit Generativer KI – ZHAW-Studenten vs. Arbeitnehmende")
    plt.xlabel("Nutzungshäufigkeit (Skala 0–10)")
    plt.ylabel("Anzahl Antworten")
    plt.legend(title="Gruppe")
    plt.grid(True)
    plt.tight_layout()
    plt.show()

    # Medianwerte berechnen und ausgeben
    median_zhaw = zhaw.median()
    median_arbeit = arbeit.median()

    print(f"📊 Median Nutzungshäufigkeit ZHAW-Studenten: {median_zhaw:.2f}")
    print(f"📊 Median Nutzungshäufigkeit Arbeitnehmende: {median_arbeit:.2f}")

else:
    print("❌ Eine oder beide der benötigten Spalten wurden nicht gefunden.")
# Out:
# 📊 Median Nutzungshäufigkeit ZHAW-Studenten: 8.00
# 📊 Median Nutzungshäufigkeit Arbeitnehmende: 7.00

# %%
import numpy as np

# Gruppenspalte
df['Gruppe'] = df['ZHAW_Student'].map({True: "ZHAW-Studenten", False: "Arbeitnehmende"})

# Daten & Beschriftung
box_data = df[[column, 'Gruppe']].dropna()
gruppe_counts = box_data['Gruppe'].value_counts()
label_order = ["ZHAW-Studenten", "Arbeitnehmende"]
xtick_labels = [f"{g}\n(n = {gruppe_counts.get(g, 0)})" for g in label_order]

# Plot
plt.figure(figsize=(10, 6))
ax = sns.boxplot(data=box_data, x="Gruppe", y=column, order=label_order,
                 palette={"ZHAW-Studenten": "blue", "Arbeitnehmende": "green"})

# Statistische Kennzahlen: Q1, Median, Q3
for i, group in enumerate(label_order):
    values = box_data[box_data["Gruppe"] == group][column].dropna()
    if len(values) == 0:
        continue

    q1 = np.percentile(values, 25)
    q3 = np.percentile(values, 75)
    median = np.median(values)

    stat_text = (f"Q1: {q1:.1f}\nMedian: {median:.1f}\nQ3: {q3:.1f}")

    # Position innerhalb der Grafik:
    if i == 0:
        # Linke Seite für ZHAW-Studenten
        x_pos = -0.45
    else:
        # Rechte Seite für Arbeitnehmende
        x_pos = -0.45

    y_pos = 10  # nah an oberer Y-Grenze

    ax.text(x=i + x_pos, y=y_pos, s=stat_text,
            ha='left', va='top', fontsize=9, color='black',
            bbox=dict(boxstyle="round,pad=0.3", fc="white", ec="gray"))

# Boxplot-Layout
plt.title("Nutzungshäufigkeit Generativer KI")
plt.xlabel("")
plt.ylabel("Nutzungshäufigkeit\n (Skala 0 = nie – 10 = sehr häufig)")
plt.xticks(ticks=[0, 1], labels=xtick_labels)
plt.grid(axis="y")
plt.tight_layout()
plt.show()
# Out:
# /var/folders/2k/c1ct_2b11hl7zvvtlkp0f5ww0000gn/T/ipykernel_8665/1007708344.py:14: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.boxplot(data=box_data, x="Gruppe", y=column, order=label_order,
